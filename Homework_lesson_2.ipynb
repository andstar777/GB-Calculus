# %% [markdown]
# <a href="https://colab.research.google.com/github/andstar777/GB-calculus/blob/main/Homework_lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Урок 2

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# __1.__ Представьте в виде __несократимой__ рациональной дроби:
#
# ### $$а)\,\,\, 0.(216);$$
# ### $$b=0.(216)$$
#
# ### $$1000b=216.(216)$$
#
# ### $$1000b=216+0.(216)$$
#
# ### $$1000b=216+b$$
#
# ### $$999b=216$$
#
# ### $$b=\frac{216}{999}=\frac{24}{111}$$
#
# ### $$0.(216)=\frac{24}{111}$$

# %% [markdown]
# __1.__ Представьте в виде __несократимой__ рациональной дроби:
#
# ### $$а)\,\,\, 1.0(01);$$
# ### $$1.0(01)=\frac{1001-10}{990}=\frac{991}{990}$$
# ### $$1.0(01)=\frac{991}{990}$$
# способом, указанным на уроке у меня не получилось решить этот пример, я нашел что есть различные способы, вот этот мне показался интересным

# %% [markdown]
# __2*.__ Пусть $x =\frac{2}{21}$. Известно, что для некоторого натурального $k$ число $x$ записывается в $k$ - ичной системе счисления как $0.(13)_k = 0, 131313..._k$. Найдите $k$.

# %% [markdown]
# __3.__ Проверьте любым способ, является ли данные логические формулы тавтологией:
#
# ### $$a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A)$$
#
# ### $$б)\,\,\, A \rightarrow (A \vee (\overline B \wedge A))$$

# %% [markdown]
# ![243480093_612908886421012_3402804028130908256_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# __4.__ Сформулируйте словесно высказывания:
# ### $$a)\,\,\, (\overline A \vee B) \rightarrow \overline C$$
# если сегодня не светит солце и сыро, то я на дачу не поеду
# ### $$б)\,\,\, C \rightarrow (A \vee \overline B)$$
# если я сегодня еду на дачу, то сегодня светит солнце и не сыро
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.

# %% [markdown]
# __5.__  Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:
#
# a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
#
# а1)∀ курсе ∀ факультета ∃ студенты, сдающие все экзамены на «отлично».
#
#  не а) не на  всех курсах каждого факультета есть студенты, сдающие экзамены на"отлично"
#
#   не а1)∃ курсе ∀ факультета ∃ студенты, сдающие все экзамены на «отлично».
#
# б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.
#
# б1) ∀ самолете на рейсе Вашингтон-Москва присутствует ∃ сотрудник силовых органов, ∀ пуговице одежды которого вмонтирован микрофон.
#
#  не б) не в каждом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, не каждой пуговице одежды которого вмонтирован микрофон.
#
# б1) ∃ самолете на рейсе Вашингтон-Москва присутствует ∃ сотрудник силовых органов, ∃ пуговице одежды которого вмонтирован микрофон.

# %% [markdown]
# __6*.__ Прочитайте высказывания, установите их истинность и постройте противоположное высказывание:
#
# ### $$a)\,\,\, \forall x\in\mathbb{R}\,\,\,\exists X\in\mathbb{R}:\,\,\, X>x;$$
#
# для каждого элемента x принадлежащего R существует хотя бы одно множество X принадлежащего R при котором X>x, ложно, *противоположное* не для каждого элемента x принадлежащего R существует хотя бы одно множество X принадлежащего R при котором X>x
# ### $$б)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\exists \varepsilon>0:\,\,\, \sin y<\sin(y+\varepsilon);$$
# для каждого 0<=y<=π/2  сущесвует хотя бы одно значение ∃ε>0  для котрых siny<sin(y+ε), значение истинно, так синус в этом диапазоне принимает значения от 0 до 1, *противоположное*  не для каждого 0<=y<=π/2  сущесвует значение ∃ε>0  для котрых siny<sin(y+ε), значение истинно будет только в ограниченном диапазоне, так синус в этом диапазоне принимает значения от 0 до 1,
#
# ### $$б1)\,\,\, \forall y\in\Bigl[0; \frac{\pi}{2}\Bigr]\,\,\,\exists \varepsilon>0:\,\,\, \sin y<\sin(y+\varepsilon);$$
#
# ### $$в)\,\,\, \forall y\in\Bigl[0; \pi\Bigr)\,\,\,\exists \varepsilon>0:\,\,\, \cos y>\cos(y+\varepsilon).$$
#
# для каждого 0<=y<π  сущесвует хотя бы одно значение ∃ε>0  для котрых cosy>cos(y+ε),значение истинно, так косинус в этом диапазоне принимает значения от -1 до 1
